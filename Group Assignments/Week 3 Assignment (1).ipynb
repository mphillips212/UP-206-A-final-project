# %% [markdown]
# # Week 3 Assignment: Analyzing Clean Energy Power Plants in California
#
# Description: I am using NAICS data from the Census Bureau to analyze clean energy power plants in California, including solar, geothermal, wind electric, and hydroelectric power. I am mapping this data by county in order to see where jobs exist in these industries across California counties.
# Author: Suzanne Caflisch

# %%
#importing geopandas for visualization of data

import geopandas as gpd

# %%
#importing census data

clean = gpd.read_file('NAICSclean.csv')

# %%
#getting general information about the data set

clean.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GEO_ID           37 non-null     object
#  1   NAME             37 non-null     object
#  2   NAICS2017        37 non-null     object
#  3   NAICS2017_LABEL  37 non-null     object
#  4   NAICS2017_F      37 non-null     object
#  5   LFO              37 non-null     object
#  6   LFO_LABEL        37 non-null     object
#  7   EMPSZES          37 non-null     object
#  8   EMPSZES_LABEL    37 non-null     object
#  9   YEAR             37 non-null     object
#  10  ESTAB            37 non-null     object
#  11  PAYANN           37 non-null     object
#  12  PAYANN_N         37 non-null     object
#  13  PAYQTR1          37 non-null     object
#  14  PAYQTR1_N        37 non-null     object
#  15  EMP              37 non-null     object
# ...

# %%
#determining the number of rows and columns in the file

clean.shape
# Out:
# (37, 18)

# %%
#examining the first rows of data

clean.head
# Out:
# <bound method NDFrame.head of             GEO_ID                                NAME        NAICS2017  \
# 0               id                Geographic Area Name  2017 NAICS code
# 1   0500000US06001          Alameda County, California           221115
# 2   0500000US06013     Contra Costa County, California           221111
# 3   0500000US06013     Contra Costa County, California           221111
# 4   0500000US06013     Contra Costa County, California           221114
# 5   0500000US06019           Fresno County, California           221111
# 6   0500000US06019           Fresno County, California           221111
# 7   0500000US06025         Imperial County, California           221116
# 8   0500000US06025         Imperial County, California           221116
# 9   0500000US06027             Inyo County, California           221111
# 10  0500000US06029             Kern County, California           221115
# 11  0500000US06029             Kern County, California           221115
# ...

# %%
#plotting the data

clean.plot(figsize=(10,10))

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
clean.sample()
# Out:
#             GEO_ID                               NAME NAICS2017  \
# 26  0500000US06071  San Bernardino County, California    221115
#
#                    NAICS2017_LABEL NAICS2017_F  LFO           LFO_LABEL  \
# 26  Wind electric power generation        null  001  All establishments
#
#    EMPSZES       EMPSZES_LABEL  YEAR ESTAB PAYANN PAYANN_N PAYQTR1 PAYQTR1_N  \
# 26     001  All establishments  2018     4  12877        J    3839         J
#
#     EMP EMP_N geometry
# 26  120     J     None

# %%
#trying to look at the first few variables in the geodata column, but running into an issue with finding a "geoid" variable.

clean.geoid.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-d4508e189b21> in <module>
# ----> 1 clean.geoid.head()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'geoid'

# %% [markdown]
# Note for graders: The file I am working with does not have spatial data associated with it. I have tried to download and import county boundaries data for CA from CA Open Data Portal, but unfortunately am not able to locate a geo_id column that matches up with the geo_id in the CBP file. Without a spatial data variable, I am unable to create maps in the jupyter notebook-- when I try the plot command, I get a blank white square (as seen above). I have emailed Yoh about this and he told me to document the issue in my notebook and seek help during OH.
